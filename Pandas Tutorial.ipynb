# %%
import pandas as pd

data = pd.read_csv("Retreat_2018_Feedback.csv")

data = data.iloc[:,1:]

data.head()
# Out:
#   Unnamed: 1  Unnamed: 2              Unnamed: 3      Unnamed: 4  \
# 0         ID  Sendedatum  ... the hotel overall?  ... the rooms?
# 1      47806  10.07.2018                       5               4
# 2      47807  10.07.2018                       5               4
# 3      47808  10.07.2018                       5               5
# 4      47809  10.07.2018                       5               5
#
#       Unnamed: 5         Unnamed: 6             Unnamed: 7  \
# 0  ... the food?  ... the SPA area?  ... the bus transfer?
# 1              4        did not use                      5
# 2              4        did not use                      5
# 3              4                  5                      5
# 4              5                  5                      5
#
#                                           Unnamed: 8            Unnamed: 9  \
# 0                                     Comments hotel  ... the ice breaker?
# ...
